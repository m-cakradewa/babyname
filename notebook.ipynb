# %%
import pandas as pd
df = pd.read_excel("baby_names.xlsx")
df.head()
# Out:
#       Name    Origin & Background               Meaning          Status  \
# 0    Adele          German/French        Noble, exalted          Common
# 1   Adelia           Latin/German        Noble, exalted          Common
# 2  Adeline          French/German        Noble, exalted  Early European
# 3    Adiva  Arabic/Islam/Sanskrit  Gentle, kind-hearted         Islamic
# 4  Adzkiya           Arabic/Islam     Intelligent, pure         Islamic
#
#            Illustration / Personality + Quirky Trait  Score
# 0  Elegant, classic European; thoughtful and grac...      0
# 1  Strong yet elegant; friendly and clever; curio...      0
# 2  Fairy-tale princess vibe; gentle, polite; imag...      0
# 3  Soft, compassionate, and nurturing; daydreamy;...      0
# 4  Radiant and virtuous; morally upright; slightl...      0

# %%
df.sort_values(by=["Origin & Background","Name"], inplace=True)
df.drop(columns=["Score"], inplace=True)
df.rename(columns={"Origin & Background":"Origin"}, inplace=True)
print(df.Origin.unique())
df.head()
# Out:
# ['Arabic/English' 'Arabic/Islam' 'Arabic/Islam/Sanskrit' 'French'
#  'French/German' 'German/English' 'German/French' 'German/Scandinavian'
#  'Greek' 'Greek/Latin' 'Greek/Scandinavian' 'Hebrew/Irish'
#  'Irish/Japanese/Arabic' 'Italian/Latin' 'Japanese/Modern' 'Latin'
#  'Latin/French' 'Latin/German' 'Latin/Greek' 'Latin/Roman'
#  'Latin/Slavic/Arabic' 'Latin/Spanish' 'Modern Arab-inspired'
#  'Nature-inspired' 'Nature-inspired / French' 'Nature-inspired / Latin'
#  'Nature-inspired / Spanish' 'Scandinavian' 'Slavic'
#  'Slavic/Arabic adaptation' 'Slavic/Greek-inspired' 'Slavic/Latin'
#  'Slavic/Persian' 'Slavic/Russian' 'Slavic/Scandinavian']
#        Name          Origin                                        Meaning  \
# 6    Alisha  Arabic/English  Noble, protected by God / variation of Alicia
# 4   Adzkiya    Arabic/Islam                              Intelligent, pure
# 8      Alya    Arabic/Islam                                   Sky, exalted
# 23    Dhiya    Arabic/Islam                                Light, radiance
# 24  Eiliyah    Arabic/Islam                        Ascending, reaching God
#
#      Status          Illustration / Personality + Quirky Trait
# 6    Common  Modern, approachable, versatile; slightly tomb...
# 4   Islamic  Radiant and virtuous; morally upright; slightl...
# 8   Islamic  Elegant, aspirational; graceful and ambitious;...
# 23  Islamic  Radiant, intelligent, morally upright; sometim...
# 24  Islamic  Spiritual and noble; calm and thoughtful; love...
